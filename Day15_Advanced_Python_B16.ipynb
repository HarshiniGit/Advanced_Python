# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[4,5,6]

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.title('Test_plot1')
# Out:
# Text(0.5, 1.0, 'Test_plot1')

# %%
plt.plot(x,y)
plt.title('Test_plot1')
# Out:
# Text(0.5, 1.0, 'Test_plot1')

# %%
plt.plot(x,y)
plt.title('Test_plot1')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.plot(x,y)
plt.title('Test_plot1')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
